# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a05w4-abc/NASSCOM-LAB/blob/main/List_Comprehensions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ── Basic list comprehension ──────────────────────────────────────────
# Generate squares of 1 to 10
# Traditional loop version:
squares_loop = []
for x in range(1, 11):
    squares_loop.append(x ** 2)

# List comprehension version (equivalent, shorter):
squares_comp = [x ** 2 for x in range(1, 11)]

print('Loop version :', squares_loop)
print('Comprehension:', squares_comp)
