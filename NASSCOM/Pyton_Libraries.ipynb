# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a05w4-abc/NASSCOM-LAB/blob/main/Pyton_Libraries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
student = {
    'name'   : 'Lalitha',
    'age'    : 37,
    'grade'  : 'A+',
    'score'  : 81
}

print(student)
print(student['name'])
print(student['grade'])
# Out:
# {'name': 'Lalitha', 'age': 37, 'grade': 'A+', 'score': 81}
# Lalitha
# A+

# %%
constants = {
    'pi'         : 3.14159265,
    'e'          : 2.71828182,
    'phi'        : 1.61803398,
    'sqrt2'      : 1.41421356,
}

print('π  =', constants['pi'])
print('e  =', constants['e'])
print('φ  =', constants['phi'])
print('√2 =', constants['sqrt2'])
# Out:
# π  = 3.14159265
# e  = 2.71828182
# φ  = 1.61803398
# √2 = 1.41421356

# %%
import os

print("Current Directory:", os.getcwd())
print("Files and Folders:", os.listdir())
os.mkdir("demo_folder")
os.rename("demo_folder", "renamed_folder")
os.rmdir("renamed_folder")
# Out:
# Current Directory: /content
# Files and Folders: ['.config', 'sample_data']

# %%
from datetime import datetime, date, timedelta

now = datetime.now()
print("Now:", now)

today = date.today()
print("Today's Date:", today)

# Create a specific date
dob = date(2000, 1, 1)
print("DOB:", dob)

# Date arithmetic
yesterday = today - timedelta(days=1)
tomorrow = today + timedelta(days=1)

print("Yesterday:", yesterday)
print("Tomorrow:", tomorrow)

# Format date to string
formatted = now.strftime("%d-%m-%Y %H:%M:%S")
print("Formatted DateTime:", formatted)
# Out:
# Now: 2026-07-31 08:23:03.513428
# Today's Date: 2026-07-31
# DOB: 2000-01-01
# Yesterday: 2026-07-30
# Tomorrow: 2026-08-01
# Formatted DateTime: 31-07-2026 08:23:03

# %%
import random

# Generate random integer between 1 and 100
print("Random Int:", random.randint(1, 100))

# Generate random float between 0 and 1
print("Random Float:", random.random())

# Choose a random item from a list
colors = ['red', 'green', 'blue']
print("Random Color:", random.choice(colors))

# Shuffle a list
random.shuffle(colors)
print("Shuffled List:", colors)

# Generate a random sample of multiple items
print("Sample:", random.sample(range(1, 50), 5))
# Out:
# Random Int: 65
# Random Float: 0.49687702614982565
# Random Color: blue
# Shuffled List: ['blue', 'red', 'green']
# Sample: [37, 23, 35, 27, 49]

# %%
from collections import Counter

# Count occurrences of elements in a list
fruits = ['Grapes','apple','Grapes', 'banana','Grapes', 'apple','Grapes', 'orange', 'banana', 'apple']
count = Counter(fruits)
print("Fruit Count:", count)
# Out:
# Fruit Count: Counter({'Grapes': 4, 'apple': 3, 'banana': 2, 'orange': 1})

# %%
from collections import defaultdict

# Returns a default value for missing keys
marks = defaultdict(lambda: 0)
marks['Math'] = 90
marks['Science'] = 80
print("Math Marks (not set):", marks['Math'])
# Out:
# Math Marks (not set): 90

# %%
from collections import namedtuple

# Create a Point object with x and y
Point = namedtuple('Point', 'x y')
p1 = Point(10, 20)
print("Point:", p1)
print("x:", p1.x, "y:", p1.y)
# Out:
# Point: Point(x=10, y=20)
# x: 10 y: 20

# %%
from collections import deque

# Double-ended queue
dq = deque([1, 2, 3])
dq.append(4)        # Add to right
dq.appendleft(0)    # Add to left
dq.pop()            # Remove from right
dq.popleft()        # Remove from left
print("Deque after operations:", dq)
# Out:
# Deque after operations: deque([1, 2, 3])
