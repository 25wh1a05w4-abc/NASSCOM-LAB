# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a05w4-abc/NASSCOM-LAB/blob/main/Statistics_and_probability.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import statistics
# ── Dataset ───────────────────────────────────────────────────────────
scores = [72, 85, 90, 68, 74, 85, 92, 78, 85, 88, 63, 91]

# ── Measures of central tendency ─────────────────────────────────────
mean   = statistics.mean(scores)
median = statistics.median(scores)
mode   = statistics.mode(scores)

print(f'Data   : {sorted(scores)}')
print(f'Mean   : {mean:.2f}')
print(f'Median : {median}')
print(f'Mode   : {mode}')
# Out:
# Data   : [63, 68, 72, 74, 78, 85, 85, 85, 88, 90, 91, 92]
# Mean   : 80.92
# Median : 85.0
# Mode   : 85

# %%
# ── Measures of spread ───────────────────────────────────────────────
import statistics
scores = [72, 85, 90, 68, 74, 85, 92, 78, 85, 88, 63, 91]

data_range  = max(scores) - min(scores)
variance    = statistics.variance(scores)
std_dev     = statistics.stdev(scores)

print(f'Range      : {data_range}')
print(f'Variance   : {variance:.2f}')
print(f'Std Dev    : {std_dev:.2f}')
# Out:
# Range      : 29
# Variance   : 93.72
# Std Dev    : 9.68

# %%
# ── Manual variance calculation to understand the formula ────────────
data = [2, 4, 4, 4, 5, 5, 7, 9]
n    = len(data)

mean_val = sum(data) / n
print(f'Mean = {mean_val}')

deviations        = [x - mean_val for x in data]
squared_devs      = [d ** 2 for d in deviations]
variance_manual   = sum(squared_devs) / n
std_dev_manual    = variance_manual ** 0.5

print(f'Deviations  : {deviations}')
print(f'Sq.Devs     : {squared_devs}')
print(f'Variance    : {variance_manual:.2f}')
print(f'Std Dev     : {std_dev_manual:.2f}')
# Out:
# Mean = 5.0
# Deviations  : [-3.0, -1.0, -1.0, -1.0, 0.0, 0.0, 2.0, 4.0]
# Sq.Devs     : [9.0, 1.0, 1.0, 1.0, 0.0, 0.0, 4.0, 16.0]
# Variance    : 4.00
# Std Dev     : 2.00

# %%
# ── Basic Probability ────────────────────────────────────────────────
total_outcomes = 6

p_roll_4 = 1 / total_outcomes
print(f'P(rolling 4)         = {p_roll_4:.4f}')
even_outcomes = 3
p_even = even_outcomes / total_outcomes
print(f'P(rolling even)      = {p_even:.4f}')

p_odd = 1 - p_even
print(f'P(rolling odd)       = {p_odd:.4f}')

p_less_3 = 2 / total_outcomes
print(f'P(rolling less than 3) = {p_less_3:.4f}')
# Out:
# P(rolling 4)         = 0.1667
# P(rolling even)      = 0.5000
# P(rolling odd)       = 0.5000
# P(rolling less than 3) = 0.3333

# %%
# ── Simulating probability with random numbers ────────────────────────
import random

random.seed(42)
n_rolls = 10000

count_even = 0

for _ in range(n_rolls):
    roll = random.randint(1, 6)
    if roll % 2 == 0:
        count_even += 1

experimental_probability = count_even / n_rolls
print(f'Rolls        : {n_rolls}')
print(f'Even count   : {count_even}')
print(f'Experimental P(even) = {experimental_probability:.4f}')
print(f'Theoretical  P(even) = 0.5000')
# Out:
# Rolls        : 10000
# Even count   : 5064
# Experimental P(even) = 0.5064
# Theoretical  P(even) = 0.5000
