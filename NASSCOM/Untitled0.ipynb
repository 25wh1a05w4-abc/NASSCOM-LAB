# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a05w4-abc/NASSCOM-LAB/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text=input("enter a paragraph:")
words=text.split()
secret=""
for line in file:
  secret+=words[0]
print("secret message:",secret)
# Out:
# enter a paragraph:honest efforts leadsto progress
# secret message: honesthonesthonesthonest
